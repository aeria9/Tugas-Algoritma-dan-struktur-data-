# %%
#Dictionary

Data = {
 "Nama" : "Dandi",
 "Kelas" : "F"
}

Data["Nama"] = "Dandi Purnomo"
Data["NIM"] = "D0221078"
Data.pop ("Kelas")

for i in Data:
 print (i,':',Data[i])
# Out:
# Nama : Dandi Purnomo
# NIM : D0221078

# %%
#List

List = [1,2,3]

List[1] = 5
List.append(4)
List.pop(3)

for i in List:
 print(i)
# Out:
# 1
# 5
# 3

# %%
#Set

Set = {1,2,3}

Set.add(4)
Set.remove(3)

for i in Set:
 print(i)
# Out:
# 1
# 2
# 4

# %%
#Tupple

Tup = 1,2,3

for i in Tup: print(i)
# Out:
# 1
# 2
# 3
